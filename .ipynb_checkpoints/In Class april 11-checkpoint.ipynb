# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# For Jupyter Notebook to display plots inline
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('project1_part2_data_cleaned.csv') 
df
# Out:
#     Unnamed: 0  ID               Name   Age         Salary  Department  \
# 0            0   1      Alice Johnson  49.0   46910.000000  Operations
# 1            1   2      Michael Smith  28.0   40206.000000          IT
# 2            2   3      Emma Williams  30.0   63419.000000       Sales
# 3            3   4        David Brown  29.0   90636.000000          HR
# 4            4   5       Olivia Jones  33.0   82143.473684   Marketing
# 5            5   6       James Garcia  55.0   94268.000000     Finance
# 6            6   7    Sophia Martinez  54.0   58141.000000  Operations
# 7            7   8  Benjamin Anderson  44.0  111910.000000   Marketing
# 8            8   9   Charlotte Thomas  45.0   96044.000000       Sales
# 9           10  11      Amelia Taylor  56.0   73827.000000  Operations
# 10          11  12      Matthew Moore  43.0   95820.000000     Finance
# 11          12  13       Isabella Lee  48.0  102623.000000          IT
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df[['Year','Avg_Temperature_degC','CO2_Emissions_tons_per_capita','Sea_Level_Rise_mm','Rainfall_mm','Population','Renewable_Energy_pct','Extreme_Weather_Events','Forest_Area_pct']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix (Seaborn)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 2
#       1 plt.figure(figsize=(10,10))
# ----> 2 sns.heatmap(df[['Year','Avg_Temperature_degC','CO2_Emissions_tons_per_capita','Sea_Level_Rise_mm','Rainfall_mm','Population','Renewable_Energy_pct','Extreme_Weather_Events','Forest_Area_pct']].corr(), annot=True, cmap='coolwarm')
#       3 plt.title("Correlation Matrix (Seaborn)")
#       4 plt.show()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
df_new = df.copy()

# %%
df_us = df_new[df_new['Country'] == 'USA']
plt.figure(figsize=(10,10))
sns.heatmap(df_us[['Year','Avg_Temperature_degC','CO2_Emissions_tons_per_capita','Sea_Level_Rise_mm','Rainfall_mm','Population','Renewable_Energy_pct','Extreme_Weather_Events','Forest_Area_pct']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix (Seaborn)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_us = df_new[df_new['Country'] == 'USA']
# ...

# %%
df_uk = df_new[df_new['Country'] == 'UK']
plt.figure(figsize=(10,10))
sns.heatmap(df_uk[['Year','Avg_Temperature_degC','CO2_Emissions_tons_per_capita','Sea_Level_Rise_mm','Rainfall_mm','Population','Renewable_Energy_pct','Extreme_Weather_Events','Forest_Area_pct']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix (Seaborn)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_uk = df_new[df_new['Country'] == 'UK']
# ...

# %%
df_sa = df_new[df_new['Country'] == "'South Africa'"]
plt.figure(figsize=(10,10))
sns.heatmap(df_sa[['Year','Avg_Temperature_degC','CO2_Emissions_tons_per_capita','Sea_Level_Rise_mm','Rainfall_mm','Population','Renewable_Energy_pct','Extreme_Weather_Events','Forest_Area_pct']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix (Seaborn)")
plt.show()

# %%
df_sa = df_new[df_new['Country'] == "China"]
plt.figure(figsize=(10,10))
sns.heatmap(df_sa[['Year','Avg_Temperature_degC','CO2_Emissions_tons_per_capita','Sea_Level_Rise_mm','Rainfall_mm','Population','Renewable_Energy_pct','Extreme_Weather_Events','Forest_Area_pct']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix (Seaborn)")
plt.show()
